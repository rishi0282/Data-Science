# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv(r'C:\Users\rishi\OneDrive\Desktop\Sabudh courseworks\LINEAR_REGRESSION\placement.csv')
dataset
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
x = dataset.iloc[:,:-1]
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y = dataset.iloc[:,-1]
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
training,test= train_test_split(dataset,test_size=0.2,random_state=45)
training
# Out:
#      cgpa  package
# 97   5.98     2.84
# 174  7.32     2.99
# 138  7.91     3.89
# 67   6.51     2.89
# 175  7.04     3.50
# ..    ...      ...
# 95   6.63     2.79
# 32   6.96     3.08
# 124  6.06     2.31
# 131  6.37     2.01
# 158  5.95     3.04
#
# [160 rows x 2 columns]

# %%
x_training = training.iloc[:,:-1]
x_training
# Out:
#      cgpa
# 97   5.98
# 174  7.32
# 138  7.91
# 67   6.51
# 175  7.04
# ..    ...
# 95   6.63
# 32   6.96
# 124  6.06
# 131  6.37
# 158  5.95
#
# [160 rows x 1 columns]

# %%
y_train = training.iloc[:,-1]
y_train
# Out:
# 97     2.84
# 174    2.99
# 138    3.89
# 67     2.89
# 175    3.50
#        ...
# 95     2.79
# 32     3.08
# 124    2.31
# 131    2.01
# 158    3.04
# Name: package, Length: 160, dtype: float64

# %%
test.count()
# Out:
# cgpa       40
# package    40
# dtype: int64

# %%
x_test = test.iloc[:,:-1]
x_test
# Out:
#      cgpa
# 45   7.87
# 72   7.78
# 40   9.38
# 58   6.92
# 25   7.28
# 13   6.93
# 153  7.94
# 80   7.63
# 3    7.42
# 44   5.09
# 134  7.20
# 149  8.28
# 173  6.75
# 33   6.35
# 62   6.34
# 182  5.88
# 112  8.58
# 129  7.29
# 69   7.30
# 190  6.19
# 133  6.05
# 172  6.93
# 35   6.87
# 157  6.47
# 187  6.26
# 10   5.32
# 104  7.62
# 177  7.09
# 26   8.31
# 171  8.01
# 147  5.66
# 0    6.89
# 109  7.77
# 194  7.89
# 151  6.12
# 82   5.58
# 64   7.36
# 169  9.31
# 4    6.94
# 28   5.94

# %%
y_test = test.iloc[:,-1]
y_test
# Out:
# 45     3.58
# 72     3.62
# 40     4.02
# 58     3.09
# 25     3.65
# 13     2.89
# 153    3.99
# 80     3.44
# 3      3.67
# 44     1.86
# 134    2.83
# 149    3.67
# 173    2.56
# 33     2.73
# 62     2.09
# 182    2.08
# 112    4.10
# 129    3.12
# 69     2.94
# 190    2.69
# 133    2.58
# 172    2.51
# 35     2.87
# 157    2.70
# 187    2.44
# 10     1.86
# 104    3.74
# 177    3.64
# 26     3.42
# 171    3.76
# 147    2.21
# 0      3.26
# 109    4.06
# 194    3.67
# 151    2.76
# 82     2.17
# 64     2.92
# 169    4.37
# 4      3.57
# 28     2.24
# Name: package, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_training,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(x_test)
# Out:
# array([3.47682571, 3.4265047 , 4.32110045, 2.94565949, 3.14694353,
#        2.95125071, 3.51596428, 3.34263635, 3.22522066, 1.9224656 ,
#        3.10221374, 3.70606587, 2.85060869, 2.62695975, 2.62136853,
#        2.36417225, 3.87380258, 3.15253475, 3.15812598, 2.53750018,
#        2.45922305, 2.95125071, 2.91770337, 2.69405443, 2.57663874,
#        2.05106374, 3.33704513, 3.04071028, 3.72283954, 3.55510284,
#        2.24116533, 2.92888582, 3.42091348, 3.48800816, 2.49836161,
#        2.19643555, 3.19167332, 4.28196189, 2.95684193, 2.39771959])

# %%
import matplotlib.pyplot as plt
plt.scatter(x_training,y_train)
plt.plot(x_training,lr.predict(x_training),color = 'red')
# plt.plot(x_test,lr.predict(x_test),color = 'pink')
plt.xlabel('CGPA')
plt.ylabel('PACKAGE')
# Out:
# Text(0, 0.5, 'PACKAGE')

# %% [markdown]
# ##### In, y = mx + b

# %%
m = lr.coef_
m
# Out:
# array([0.55912234])

# %%
b = lr.intercept_
b
# Out:
# -0.9234671310599816

# %%
lr.predict([[8.48]])
# Out:
# c:\Users\rishi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.81789034])
